# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r"C:\Users\start\Downloads\Titanic.csv")

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
df['Cabin'].fillna("NO",inplace=True)
# Out:
# C:\Users\start\AppData\Local\Temp\ipykernel_12888\4049242439.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Cabin'].fillna("NO",inplace=True)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ..                                            ...     ...   ...    ...    ...
# 413                            Spector, Mr. Woolf    male   NaN      0      0
# 414                  Oliva y Ocana, Dona. Fermina  female  39.0      0      0
# 415                  Saether, Mr. Simon Sivertsen    male  38.5      0      0
# 416                           Ware, Mr. Frederick    male   NaN      0      0
# 417                      Peter, Master. Michael J    male   NaN      1      1
#
#                  Ticket      Fare Cabin Embarked
# 0                330911    7.8292    NO        Q
# 1                363272    7.0000    NO        S
# 2                240276    9.6875    NO        Q
# 3                315154    8.6625    NO        S
# 4               3101298   12.2875    NO        S
# ..                  ...       ...   ...      ...
# 413           A.5. 3236    8.0500    NO        S
# 414            PC 17758  108.9000  C105        C
# 415  SOTON/O.Q. 3101262    7.2500    NO        S
# 416              359309    8.0500    NO        S
# 417                2668   22.3583    NO        C
#
# [418 rows x 12 columns]

# %%
df['Pclass'].replace({1: 'Class 1', 2: 'Class 2', 3: 'Class 3'}, inplace=True)
# Out:
# C:\Users\start\AppData\Local\Temp\ipykernel_12888\2705510774.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Pclass'].replace({1: 'Class 1', 2: 'Class 2', 3: 'Class 3'}, inplace=True)

# %%
df.head()
# Out:
#    PassengerId  Survived   Pclass  \
# 0          892         0  Class 3
# 1          893         1  Class 3
# 2          894         0  Class 2
# 3          895         0  Class 3
# 4          896         1  Class 3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292    NO        Q
# 1   363272   7.0000    NO        S
# 2   240276   9.6875    NO        Q
# 3   315154   8.6625    NO        S
# 4  3101298  12.2875    NO        S

# %%
class_counts = df['Pclass'].value_counts()
class_counts
# Out:
# Pclass
# Class 3    218
# Class 1    107
# Class 2     93
# Name: count, dtype: int64

# %%
plt.bar(class_counts.index, class_counts.values)
plt.xlabel('Passenger class')
plt.ylabel('Count')
plt.title('Number of passengers in each class')
plt.show()

# %%
suvival = df['Survived'].value_counts()
suvival
# Out:
# Survived
# 0    266
# 1    152
# Name: count, dtype: int64

# %%
plt.hist(df.Age,bins=35)
plt.show()

# %%
df['Survived'].replace({1: 'Survived', 0: 'Not Survived'}, inplace=True)
# Out:
# C:\Users\start\AppData\Local\Temp\ipykernel_12888\583382143.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Survived'].replace({1: 'Survived', 0: 'Not Survived'}, inplace=True)

# %%
df.head()
# Out:
#    PassengerId      Survived   Pclass  \
# 0          892  Not Survived  Class 3
# 1          893      Survived  Class 3
# 2          894  Not Survived  Class 2
# 3          895  Not Survived  Class 3
# 4          896      Survived  Class 3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292    NO        Q
# 1   363272   7.0000    NO        S
# 2   240276   9.6875    NO        Q
# 3   315154   8.6625    NO        S
# 4  3101298  12.2875    NO        S

# %%
sur_counts=df['Survived'].value_counts()
plt.bar(sur_counts.index, sur_counts.values)
plt.xlabel('survived')
plt.ylabel('Count')
plt.title('Number of Survived or Not')
plt.show()

# %%
df['Age'].plot(kind = 'box')
plt.show()

# %%
df['Fare'].plot(kind = 'box')
plt.show()
